# %%
# Basic libraries
import numpy as np
import pandas as pd
import datetime
from dateutil.relativedelta import relativedelta

# Normalization libraries
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from sklearn.decomposition import PCA
import pickle as pk

# Auxiliar libraries
from datetime import datetime, timedelta
from datetime import date

# %%
n='12'

# %%
df_mape_0 = pd.read_csv('/Users/oliviagutu/Desktop/YANET/MODELO_M3_DATASET_26_sep/outputs/daily_mape/mape__[' + n +']_.csv', parse_dates=True)
df_mape_1 = pd.read_csv('/Users/oliviagutu/Desktop/YANET/MODELO_M3_DATASET_26_sep_menos_1/outputs/daily_mape/mape__[' + n +']_.csv', parse_dates=True)
df_mape_2 = pd.read_csv('/Users/oliviagutu/Desktop/YANET/MODELO_M3_DATASET_26_sep_menos_2/outputs/daily_mape/mape__[' + n +']_.csv', parse_dates=True)
df_mape_3 = pd.read_csv('/Users/oliviagutu/Desktop/YANET/MODELO_M3_DATASET_26_sep_menos_3/outputs/daily_mape/mape__[' + n +']_.csv', parse_dates=True)
df_mape_4 = pd.read_csv('/Users/oliviagutu/Desktop/YANET/MODELO_M3_DATASET_26_sep_menos_4/outputs/daily_mape/mape__[' + n +']_.csv', parse_dates=True)
df_mape_5 = pd.read_csv('/Users/oliviagutu/Desktop/YANET/MODELO_M3_DATASET_26_sep_menos_5/outputs/daily_mape/mape__[' + n +']_.csv', parse_dates=True)
df_mape_6 = pd.read_csv('/Users/oliviagutu/Desktop/YANET/MODELO_M3_DATASET_26_sep_menos_6/outputs/daily_mape/mape__[' + n +']_.csv', parse_dates=True)
df_mape_7 = pd.read_csv('/Users/oliviagutu/Desktop/YANET/MODELO_M3_DATASET_26_sep_menos_7/outputs/daily_mape/mape__[' + n +']_.csv', parse_dates=True)
df_mape_8 = pd.read_csv('/Users/oliviagutu/Desktop/YANET/MODELO_M3_DATASET_26_sep_menos_8/outputs/daily_mape/mape__[' + n +']_.csv', parse_dates=True)
df_mape_9 = pd.read_csv('/Users/oliviagutu/Desktop/YANET/MODELO_M3_DATASET_26_sep_menos_9/outputs/daily_mape/mape__[' + n +']_.csv', parse_dates=True)
df_mape_10 = pd.read_csv('/Users/oliviagutu/Desktop/YANET/MODELO_M3_DATASET_26_sep_menos_10/outputs/daily_mape/mape__[' + n +']_.csv', parse_dates=True)
df_mape_11 = pd.read_csv('/Users/oliviagutu/Desktop/YANET/MODELO_M3_DATASET_26_sep_menos_11/outputs/daily_mape/mape__[' + n +']_.csv', parse_dates=True)

# %%
frames = [df_mape_0,df_mape_1,df_mape_2,df_mape_3,df_mape_4,df_mape_5,df_mape_6,df_mape_7,df_mape_8,df_mape_9,df_mape_10,df_mape_11]
df_total = pd.concat(frames).iloc[: , 1:]
df_total
# Out:
#           Date  Mape_M_1  Mape_M_2  Mape_M_3  Mape_M_4
# 0   2023-08-14  3.106482  2.064238  2.277030  1.438299
# 1   2023-08-15  1.582707  1.747482  1.088307  3.571066
# 2   2023-08-16  1.871464  1.533202  1.668605  3.721969
# 3   2023-08-17  1.378995  3.896543  4.441041  5.447727
# 4   2023-08-18  0.887021  3.517081  3.208859  2.585271
# ..         ...       ...       ...       ...       ...
# 16  2022-09-30  2.222097  1.293600  1.545491  2.588756
# 17  2022-10-01  2.914593  1.763064  1.841833  2.460852
# 18  2022-10-02  3.185527  1.816921  1.805671  2.509217
# 19  2022-10-03  1.433431  2.020059  1.762656  1.410578
# 20  2022-10-04  3.399793  3.675763  2.607757  2.730941
#
# [257 rows x 5 columns]

# %%
df_total.to_csv('Mape_['+n+'].csv')
